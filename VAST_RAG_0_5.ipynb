# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_dir = "/content/drive/MyDrive/FYP/dataset/Facts(1).csv"

# %%
# import locale
# locale.getpreferredencoding = lambda: "UTF-8"

# %%
# pip install openai

# %%
# pip install spacy

# %%
# !pip install -qU \
  transformers==4.31.0 \
  sentence-transformers==2.2.2 \
  pinecone-client==2.2.2 \
  datasets==2.14.0 \
  accelerate==0.21.0 \
  einops==0.6.1 \
  langchain==0.0.240 \
  xformers==0.0.20 \
  bitsandbytes==0.41.0
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 19.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 10.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.1/179.1 kB 16.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.2/492.2 kB 22.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 9.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 23.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.1/109.1 MB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 61.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 73.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

df = pd.read_csv(data_dir)

sentences = df['sentence'].tolist()

# %%
sentences
# Out:
# ['I am your campus friendly bot named VAST (Varsity Academic support tool). I can help you with academic, administrative, navigational and general queries. What can I help you with?',
#  "Hey there, I'm VAST, your helpful campus bot. What do you need assistance with?",
#  'Greetings! VAST at your service. Feel free to ask anything related to academics or administration.',
#  "Hi, I'm VAST your friendly campus tool. How can I assist you today?",
#  'I came to life on December 6th, 2023, thanks to an FYP group.',
#  'An FYP group brought me into existence on December 6th, 2023.',
#  'December 6th, 2023, marks the day I was developed by an FYP group.',
#  'I was developed by an FYP group on December 6th, 2023.',
#  'I am sorry, I do not want to marry you.',
#  'Love, hate, anger, grief are all human emotions. I do not feel anything. I can help you with academic, administrative, navigational and general queries. How may I help you?',
# ...

# %%
from torch import cuda
from langchain.embeddings.huggingface import HuggingFaceEmbeddings

embed_model_id = 'sentence-transformers/all-MiniLM-L6-v2'

device = f'cuda:{cuda.current_device()}' if cuda.is_available() else 'cpu'

embed_model = HuggingFaceEmbeddings(
    model_name=embed_model_id,
    model_kwargs={'device': device},
    encode_kwargs={'device': device, 'batch_size': 32}
)
# Out:
# .gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
embeddings = embed_model.embed_documents(sentences)

print(f"We have {len(embeddings)} doc embeddings, each with "
      f"a dimensionality of {len(embeddings[0])}.")
# Out:
# We have 172 doc embeddings, each with a dimensionality of 384.

# %%
# from langchain.embeddings.openai import OpenAIEmbeddings

# %%
# OPENAI_API_KEY='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'
# embed_model = OpenAIEmbeddings(openai_api_key=OPENAI_API_KEY)  # Use default model

# # Optionally, specify a different model:
# # embed_model = OpenAIEmbeddings(model="text-embedding-ada-002")

# %%
# pip install tiktoken

# %%
# # Embed a list of documents
# embeddings = embed_model.embed_documents(sentences[0])

# # # Embed a single query
# # query_embedding = embed_model.embed_query("Your query here")

# %%
import os
import pinecone

# get API key from app.pinecone.io and environment from console
pinecone.init(
    api_key=os.environ.get('ad61dbbb-6649-4b33-a343-40e905189d86') or 'ad61dbbb-6649-4b33-a343-40e905189d86',
    environment=os.environ.get('gcp-starter') or 'gcp-starter'
)

# %%
import time

index_name = 'llama-2-rag'

if index_name not in pinecone.list_indexes():
    pinecone.create_index(
        index_name,
        dimension=len(embeddings[0]),
        metric='cosine'
    )
    # index intialize wait
    while not pinecone.describe_index(index_name).status['ready']:
        time.sleep(1)

# %%
index = pinecone.Index(index_name)
index.describe_index_stats()
# Out:
# {'dimension': 384,
#  'index_fullness': 0.00256,
#  'namespaces': {'': {'vector_count': 256}},
#  'total_vector_count': 256}

# %%
# !pip install PyPDF2

# %%
# pip install python-docx2txt

# %%
# Assuming you have a Pinecone index instance named 'index'
batch_size = 512

for i in range(0, len(sentences), batch_size):
    i_end = min(len(sentences), i + batch_size)
    batch = sentences[i:i_end]

    # Generating unique identifiers for each sentence
    ids = [f"sentence_{i}" for i in range(len(batch))]

    # Use embed_documents to embed the batch of sentences
    embeds = embed_model.embed_documents(batch)

    # get metadata to store in Pinecone
    metadata = [{'text': sentence} for sentence in batch]

    # add to Pinecone
    index.upsert(vectors=zip(ids, embeds, metadata))

# %%
index.describe_index_stats()
# Out:
# {'dimension': 384,
#  'index_fullness': 0.00256,
#  'namespaces': {'': {'vector_count': 256}},
#  'total_vector_count': 256}

# %%
from torch import cuda, bfloat16
import transformers

model_id = 'meta-llama/Llama-2-7b-chat-hf'

device = f'cuda:{cuda.current_device()}' if cuda.is_available() else 'cpu'

# set quantization configuration to load large model with less GPU memory
# this requires the `bitsandbytes` library
bnb_config = transformers.BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type='nf4',
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=bfloat16
)

# begin initializing HF items, need auth token for these
hf_auth = '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'
model_config = transformers.AutoConfig.from_pretrained(
    model_id,
    use_auth_token=hf_auth
)

model = transformers.AutoModelForCausalLM.from_pretrained(
    model_id,
    trust_remote_code=True,
    config=model_config,
    quantization_config=bnb_config,
    device_map='auto',
    use_auth_token=hf_auth
)
model.eval()
print(f"Model loaded on {device}")
# Out:
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:2193: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# ...
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]
# Model loaded on cuda:0

# %%
tokenizer = transformers.AutoTokenizer.from_pretrained(
    model_id,
    use_auth_token=hf_auth
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1714: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %%
generate_text = transformers.pipeline(
    model=model, tokenizer=tokenizer,
    return_full_text=True,
    task='text-generation',
    temperature=0.0,  # randomness of outputs
    max_new_tokens=512,
    repetition_penalty=1.2
)

# %%
# res = generate_text("Explain to me the difference between nuclear fission and fusion.")
# print(res[0]["generated_text"])

# %%
from langchain.llms import HuggingFacePipeline

llm = HuggingFacePipeline(pipeline=generate_text)

# %%
from langchain.vectorstores import Pinecone

text_field = 'text'  # field in metadata that contains text content

vectorstore = Pinecone(
    index, embed_model.embed_query, text_field
)

# %%
query = 'rafi'

vectorstore.similarity_search(
    query,
    k=5  # returns top 3 most relevant chunks of text
)
# Out:
# [Document(page_content="Dr. Muhammad Rafi is the AI department's Head.", metadata={}),
#  Document(page_content='Dr. Muhammad Rafi is the HOD of the AI department.', metadata={}),
#  Document(page_content='Head of the AI department is Dr. Muhammad Rafi.', metadata={}),
#  Document(page_content='Leading the AI department is Dr. Muhammad Rafi.', metadata={}),
#  Document(page_content='When you enter from the main gate, the Futsal ground is on your left.', metadata={})]

# %%
from langchain.chains import RetrievalQA

rag_pipeline = RetrievalQA.from_chain_type(
    llm=llm, chain_type='stuff',
    retriever=vectorstore.as_retriever(),
    verbose = True
)

# %%
# llm('who is rafi')

# %%
result = rag_pipeline('tell me the names of all the HOD')
# Out:
# > Entering new RetrievalQA chain...
#
# > Finished chain.

# %%
result[result]
# Out:
# {'query': 'tell me the names of all the HOD',
#  'result': ' Sure! Based on the information provided in the passage, here are the names of the Heads of Department (HODs): Dr. Muhammad Rafi (AI), Dr. Zulfiqar Ali Memon (Computer Science), Dr. Abdul Aziz (Software Engineering), and Dr. Fahad Samad (Cyber Security).'}
